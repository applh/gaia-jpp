# %%
# https://docs.blender.org/manual/en/latest/advanced/command_line/arguments.html

# blender scene 
blender_file = "scene"

# get timestamp ymd-his
timestamp = !date +"%y%m%d-%H%M%S"
timestamp = timestamp[0]
video_name = f"{blender_file}-{timestamp}.mp4"

frame_start = 1
frame_end = 1800

# launch blender render in background and save in video_name
# !blender -b blender/{blender_file}.blend -s {frame_start} -e {frame_end} -P blender/render.py -o //my-video/{video_name} -a

#!blender -b -P scene/render.py blender/scene.blend -s 1 -e 100 -o //my-video/scene-$(date +"%y%m%d-%H%M%S").mp4 -a

# show webm file 001-0300.webm
from IPython.display import HTML
html_code = '<video width="100%" height="400" controls autoplay loop><source src="./blender/my-video/' + video_name + '"></video>'
video = HTML(html_code)

print(video_name)
# !ls -lh ./blender/my-video/{video_name}
display(video)
# Out:
# Blender 3.5.0 (hash 1be25cfff18b built 2023-03-29 06:34:18)
# Read prefs: /Users/lh/Library/Application Support/Blender/3.5/config/userpref.blend
# Device with name Apple M1 supports metal minimum requirements
# Read blend: /Users/lh/Documents/2023/gaia-jpp/python/blender/scene.blend
# METAL API - DETECTED GPU: Apple M1
# Fra:1 Mem:54.91M (Peak 55.65M) | Time:00:00.12 | Syncing Cube
# Fra:1 Mem:55.09M (Peak 55.65M) | Time:00:00.70 | Syncing Light
# Fra:1 Mem:55.09M (Peak 55.65M) | Time:00:00.70 | Syncing Camera
# Fra:1 Mem:55.09M (Peak 55.65M) | Time:00:00.70 | Syncing Camera_target
# Fra:1 Mem:55.10M (Peak 55.65M) | Time:00:00.70 | Syncing Ground
# Fra:1 Mem:55.26M (Peak 55.65M) | Time:00:00.98 | Syncing Sphere
# Fra:1 Mem:59.43M (Peak 63.29M) | Time:00:01.32 | Rendering 1 / 5 samples
# Fra:1 Mem:59.54M (Peak 63.29M) | Time:00:01.49 | Rendering 4 / 4 samples
# Append frame 1
#  Time: 00:01.70 (Saving: 00:00.13)
#
# Fra:2 Mem:59.39M (Peak 113.34M) | Time:00:00.00 | Syncing Cube
# Fra:2 Mem:59.39M (Peak 113.34M) | Time:00:00.00 | Syncing Light
# Fra:2 Mem:59.39M (Peak 113.34M) | Time:00:00.00 | Syncing Camera
# Fra:2 Mem:59.39M (Peak 113.34M) | Time:00:00.00 | Syncing Camera_target
# Fra:2 Mem:59.39M (Peak 113.34M) | Time:00:00.00 | Syncing Ground
# Fra:2 Mem:59.40M (Peak 113.34M) | Time:00:00.00 | Syncing Sphere
# Fra:2 Mem:59.55M (Peak 113.34M) | Time:00:00.00 | Rendering 1 / 5 samples
# Fra:2 Mem:59.55M (Peak 113.34M) | Time:00:00.12 | Rendering 4 / 4 samples
# Append frame 2
#  Time: 00:00.21 (Saving: 00:00.04)
#
# Fra:3 Mem:59.39M (Peak 113.34M) | Time:00:00.00 | Syncing Cube
# Fra:3 Mem:59.39M (Peak 113.34M) | Time:00:00.00 | Syncing Light
# Fra:3 Mem:59.39M (Peak 113.34M) | Time:00:00.00 | Syncing Camera
# Fra:3 Mem:59.39M (Peak 113.34M) | Time:00:00.00 | Syncing Camera_target
# Fra:3 Mem:59.39M (Peak 113.34M) | Time:00:00.00 | Syncing Ground
# Fra:3 Mem:59.40M (Peak 113.34M) | Time:00:00.00 | Syncing Sphere
# Fra:3 Mem:59.55M (Peak 113.34M) | Time:00:00.00 | Rendering 1 / 5 samples
# Fra:3 Mem:59.55M (Peak 113.34M) | Time:00:00.12 | Rendering 4 / 4 samples
# Append frame 3
#  Time: 00:00.22 (Saving: 00:00.05)
#
# Fra:4 Mem:59.39M (Peak 113.34M) | Time:00:00.00 | Syncing Cube
# Fra:4 Mem:59.39M (Peak 113.34M) | Time:00:00.00 | Syncing Light
# Fra:4 Mem:59.39M (Peak 113.34M) | Time:00:00.00 | Syncing Camera
# Fra:4 Mem:59.39M (Peak 113.34M) | Time:00:00.00 | Syncing Camera_target
# Fra:4 Mem:59.39M (Peak 113.34M) | Time:00:00.00 | Syncing Ground
# Fra:4 Mem:59.40M (Peak 113.34M) | Time:00:00.00 | Syncing Sphere
# Fra:4 Mem:59.55M (Peak 113.34M) | Time:00:00.00 | Rendering 1 / 5 samples
# Fra:4 Mem:59.55M (Peak 113.34M) | Time:00:00.11 | Rendering 4 / 4 samples
# Append frame 4
#  Time: 00:00.22 (Saving: 00:00.05)
#
# Fra:5 Mem:59.40M (Peak 113.34M) | Time:00:00.00 | Syncing Cube
# Fra:5 Mem:59.40M (Peak 113.34M) | Time:00:00.00 | Syncing Light
# Fra:5 Mem:59.40M (Peak 113.34M) | Time:00:00.00 | Syncing Camera
# Fra:5 Mem:59.40M (Peak 113.34M) | Time:00:00.00 | Syncing Camera_target
# Fra:5 Mem:59.40M (Peak 113.34M) | Time:00:00.00 | Syncing Ground
# Fra:5 Mem:59.40M (Peak 113.34M) | Time:00:00.00 | Syncing Sphere
# Fra:5 Mem:59.55M (Peak 113.34M) | Time:00:00.00 | Rendering 1 / 5 samples
# Fra:5 Mem:59.55M (Peak 113.34M) | Time:00:00.12 | Rendering 4 / 4 samples
# Append frame 5
#  Time: 00:00.21 (Saving: 00:00.05)
#
# Fra:6 Mem:59.40M (Peak 113.35M) | Time:00:00.00 | Syncing Cube
# Fra:6 Mem:59.40M (Peak 113.35M) | Time:00:00.00 | Syncing Light
# Fra:6 Mem:59.40M (Peak 113.35M) | Time:00:00.00 | Syncing Camera
# Fra:6 Mem:59.40M (Peak 113.35M) | Time:00:00.00 | Syncing Camera_target
# Fra:6 Mem:59.40M (Peak 113.35M) | Time:00:00.00 | Syncing Ground
# Fra:6 Mem:59.40M (Peak 113.35M) | Time:00:00.00 | Syncing Sphere
# Fra:6 Mem:59.55M (Peak 113.35M) | Time:00:00.00 | Rendering 1 / 5 samples
# Fra:6 Mem:59.55M (Peak 113.35M) | Time:00:00.12 | Rendering 4 / 4 samples
# Append frame 6
#  Time: 00:00.22 (Saving: 00:00.05)
#
# Fra:7 Mem:59.40M (Peak 113.35M) | Time:00:00.00 | Syncing Cube
# Fra:7 Mem:59.40M (Peak 113.35M) | Time:00:00.00 | Syncing Light
# Fra:7 Mem:59.40M (Peak 113.35M) | Time:00:00.00 | Syncing Camera
# Fra:7 Mem:59.40M (Peak 113.35M) | Time:00:00.00 | Syncing Camera_target
# Fra:7 Mem:59.40M (Peak 113.35M) | Time:00:00.00 | Syncing Ground
# Fra:7 Mem:59.40M (Peak 113.35M) | Time:00:00.00 | Syncing Sphere
# Fra:7 Mem:59.55M (Peak 113.35M) | Time:00:00.00 | Rendering 1 / 5 samples
# Fra:7 Mem:59.55M (Peak 113.35M) | Time:00:00.12 | Rendering 4 / 4 samples
# Append frame 7
#  Time: 00:00.21 (Saving: 00:00.05)
#
# Fra:8 Mem:59.40M (Peak 113.35M) | Time:00:00.00 | Syncing Cube
# Fra:8 Mem:59.40M (Peak 113.35M) | Time:00:00.00 | Syncing Light
# Fra:8 Mem:59.40M (Peak 113.35M) | Time:00:00.00 | Syncing Camera
# Fra:8 Mem:59.40M (Peak 113.35M) | Time:00:00.00 | Syncing Camera_target
# Fra:8 Mem:59.40M (Peak 113.35M) | Time:00:00.00 | Syncing Ground
# Fra:8 Mem:59.40M (Peak 113.35M) | Time:00:00.00 | Syncing Sphere
# Fra:8 Mem:59.55M (Peak 113.35M) | Time:00:00.00 | Rendering 1 / 5 samples
# Fra:8 Mem:59.55M (Peak 113.35M) | Time:00:00.12 | Rendering 4 / 4 samples
# Append frame 8
#  Time: 00:00.22 (Saving: 00:00.05)
#
# Fra:9 Mem:59.40M (Peak 113.35M) | Time:00:00.00 | Syncing Cube
# Fra:9 Mem:59.40M (Peak 113.35M) | Time:00:00.00 | Syncing Light
# Fra:9 Mem:59.40M (Peak 113.35M) | Time:00:00.00 | Syncing Camera
# Fra:9 Mem:59.40M (Peak 113.35M) | Time:00:00.00 | Syncing Camera_target
# Fra:9 Mem:59.40M (Peak 113.35M) | Time:00:00.00 | Syncing Ground
# Fra:9 Mem:59.40M (Peak 113.35M) | Time:00:00.00 | Syncing Sphere
# Fra:9 Mem:59.55M (Peak 113.35M) | Time:00:00.00 | Rendering 1 / 5 samples
# Fra:9 Mem:59.55M (Peak 113.35M) | Time:00:00.12 | Rendering 4 / 4 samples
# Append frame 9
#  Time: 00:00.21 (Saving: 00:00.05)
#
# Fra:10 Mem:59.40M (Peak 113.35M) | Time:00:00.00 | Syncing Cube
# Fra:10 Mem:59.40M (Peak 113.35M) | Time:00:00.00 | Syncing Light
# Fra:10 Mem:59.40M (Peak 113.35M) | Time:00:00.00 | Syncing Camera
# Fra:10 Mem:59.40M (Peak 113.35M) | Time:00:00.00 | Syncing Camera_target
# Fra:10 Mem:59.40M (Peak 113.35M) | Time:00:00.00 | Syncing Ground
# Fra:10 Mem:59.40M (Peak 113.35M) | Time:00:00.00 | Syncing Sphere
# Fra:10 Mem:59.55M (Peak 113.35M) | Time:00:00.00 | Rendering 1 / 5 samples
# Fra:10 Mem:59.55M (Peak 113.35M) | Time:00:00.12 | Rendering 4 / 4 samples
# Append frame 10
#  Time: 00:00.21 (Saving: 00:00.05)
#
# Fra
Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Light
# Fra:58 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera
# Fra:58 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera_target
# Fra:58 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Ground
# Fra:58 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Sphere
# Fra:58 Mem:59.57M (Peak 113.59M) | Time:00:00.00 | Rendering 1 / 5 samples
# Fra:58 Mem:59.56M (Peak 113.59M) | Time:00:00.12 | Rendering 4 / 4 samples
# Append frame 58
#  Time: 00:00.22 (Saving: 00:00.05)
#
# Fra:59 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Cube
# Fra:59 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Light
# Fra:59 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera
# Fra:59 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera_target
# Fra:59 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Ground
# Fra:59 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Sphere
# Fra:59 Mem:59.57M (Peak 113.59M) | Time:00:00.00 | Rendering 1 / 5 samples
# Fra:59 Mem:59.56M (Peak 113.59M) | Time:00:00.12 | Rendering 4 / 4 samples
# Append frame 59
#  Time: 00:00.22 (Saving: 00:00.05)
#
# Fra:60 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Cube
# Fra:60 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Light
# Fra:60 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera
# Fra:60 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera_target
# Fra:60 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Ground
# Fra:60 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Sphere
# Fra:60 Mem:59.57M (Peak 113.59M) | Time:00:00.00 | Rendering 1 / 5 samples
# Fra:60 Mem:59.56M (Peak 113.59M) | Time:00:00.12 | Rendering 4 / 4 samples
# Append frame 60
#  Time: 00:00.23 (Saving: 00:00.05)
#
# Fra:61 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Cube
# Fra:61 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Light
# Fra:61 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera
# Fra:61 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera_target
# Fra:61 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Ground
# Fra:61 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Sphere
# Fra:61 Mem:59.57M (Peak 113.59M) | Time:00:00.00 | Rendering 1 / 5 samples
# Fra:61 Mem:59.56M (Peak 113.59M) | Time:00:00.13 | Rendering 4 / 4 samples
# Append frame 61
#  Time: 00:00.22 (Saving: 00:00.05)
#
# Fra:62 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Cube
# Fra:62 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Light
# Fra:62 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera
# Fra:62 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera_target
# Fra:62 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Ground
# Fra:62 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Sphere
# Fra:62 Mem:59.57M (Peak 113.59M) | Time:00:00.00 | Rendering 1 / 5 samples
# Fra:62 Mem:59.56M (Peak 113.59M) | Time:00:00.13 | Rendering 4 / 4 samples
# Append frame 62
#  Time: 00:00.23 (Saving: 00:00.05)
#
# Fra:63 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Cube
# Fra:63 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Light
# Fra:63 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera
# Fra:63 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera_target
# Fra:63 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Ground
# Fra:63 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Sphere
# Fra:63 Mem:59.57M (Peak 113.59M) | Time:00:00.00 | Rendering 1 / 5 samples
# Fra:63 Mem:59.56M (Peak 113.59M) | Time:00:00.12 | Rendering 4 / 4 samples
# Append frame 63
#  Time: 00:00.22 (Saving: 00:00.05)
#
# Fra:64 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Cube
# Fra:64 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Light
# Fra:64 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera
# Fra:64 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera_target
# Fra:64 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Ground
# Fra:64 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Sphere
# Fra:64 Mem:59.57M (Peak 113.59M) | Time:00:00.00 | Rendering 1 / 5 samples
# Fra:64 Mem:59.56M (Peak 113.59M) | Time:00:00.12 | Rendering 4 / 4 samples
# Append frame 64
#  Time: 00:00.22 (Saving: 00:00.05)
#
# Fra:65 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Cube
# Fra:65 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Light
# Fra:65 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera
# Fra:65 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera_target
# Fra:65 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Ground
# Fra:65 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Sphere
# Fra:65 Mem:59.57M (Peak 113.59M) | Time:00:00.00 | Rendering 1 / 5 samples
# Fra:65 Mem:59.57M (Peak 113.59M) | Time:00:00.13 | Rendering 4 / 4 samples
# Append frame 65
#  Time: 00:00.23 (Saving: 00:00.05)
#
# Fra:66 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Cube
# Fra:66 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Light
# Fra:66 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera
# Fra:66 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera_target
# Fra:66 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Ground
# Fra:66 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Sphere
# Fra:66 Mem:59.57M (Peak 113.59M) | Time:00:00.00 | Rendering 1 / 5 samples
# Fra:66 Mem:59.57M (Peak 113.59M) | Time:00:00.13 | Rendering 4 / 4 samples
# Append frame 66
#  Time: 00:00.23 (Saving: 00:00.05)
#
# Fra:67 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Cube
# Fra:67 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Light
# Fra:67 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera
# Fra:67 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera_target
# Fra:67 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Ground
# Fra:67 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Sphere
# Fra:67 Mem:59.57M (Peak 113.59M) | Time:00:00.00 | Rendering 1 / 5 samples
# Fra:67 Mem:59.57M (Peak 113.59M) | Time:00:00.13 | Rendering 4 / 4 samples
# Append frame 67
#  Time: 00:00.23 (Saving: 00:00.05)
#
# Fra:68 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Cube
# Fra:68 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Light
# Fra:68 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera
# Fra:68 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera_target
# Fra:68 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Ground
# Fra:68 Mem:59.42M (Peak 113.59M) | Time:00:00.00 | Syncing Sphere
# Fra:68 Mem:59.58M (Peak 113.59M) | Time:00:00.00 | Rendering 1 / 5 samples
# Fra:68 Mem:59.57M (Peak 113.59M) | Time:00:00.13 | Rendering 4 / 4 samples
# Append frame 68
#  Time: 00:00.23 (Saving: 00:00.05)
#
# Fra:69 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Cube
# Fra:69 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Light
# Fra:69 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera
# Fra:69 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera_target
# Fra:69 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Ground
# Fra:69 Mem:59.42M (Peak 113.59M) | Time:00:00.00 | Syncing Sphere
# Fra:69 Mem:59.58M (Peak 113.59M) | Time:00:00.00 | Rendering 1 / 5 samples
# Fra:69 Mem:59.57M (Peak 113.59M) | Time:00:00.12 | Rendering 4 / 4 samples
# Append frame 69
#  Time: 00:00.22 (Saving: 00:00.05)
#
# Fra:70 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Cube
# Fra:70 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Light
# Fra:70 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera
# Fra:70 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera_target
# Fra:70 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Ground
# Fra:70 Mem:59.42M (Peak 113.59M) | Time:00:00.00 | Syncing Sphere
# Fra:70 Mem:59.58M (Peak 113.59M) | Time:00:00.00 | Rendering 1 / 5 samples
# Fra:70 Mem:59.57M (Peak 113.59M) | Time:00:00.13 | Rendering 4 / 4 samples
# Append frame 70
#  Time: 00:00.22 (Saving: 00:00.04)
#
# Fra:71 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Cube
# Fra:71 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Light
# Fra:71 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera
# Fra:71 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera_target
# Fra:71 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Ground
# Fra:71 Mem:59.42M (Peak 113.59M) | Time:00:00.00 | Syncing Sphere
# Fra:71 Mem:59.58M (Peak 113.59M) | Time:00:00.00 | Rendering 1 / 5 samples
# Fra:71 Mem:59.57M (Peak 113.59M) | Time:00:00.13 | Rendering 4 / 4 samples
# Append frame 71
#  Time: 00:00.23 (Saving: 00:00.05)
#
# Fra:72 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Cube
# Fra:72 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Light
# Fra:72 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera
# Fra:72 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera_target
# Fra:72 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Ground
# Fra:72 Mem:59.42M (Peak 113.59M) | Time:00:00.00 | Syncing Sphere
# Fra:72 Mem:59.58M (Peak 113.59M) | Time:00:00.00 | Rendering 1 / 5 samples
# Fra:72 Mem:59.57M (Peak 113.59M) | Time:00:00.12 | Rendering 4 / 4 samples
# Append frame 72
#  Time: 00:00.22 (Saving: 00:00.05)
#
# Fra:73 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Cube
# Fra:73 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Light
# Fra:73 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera
# Fra:73 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera_target
# Fra:73 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Ground
# Fra:73 Mem:59.42M (Peak 113.59M) | Time:00:00.00 | Syncing Sphere
# Fra:73 Mem:59.58M (Peak 113.59M) | Time:00:00.00 | Rendering 1 / 5 samples
# Fra:73 Mem:59.57M (Peak 113.59M) | Time:00:00.13 | Rendering 4 / 4 samples
# Append frame 73
#  Time: 00:00.23 (Saving: 00:00.05)
#
# Fra:74 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Cube
# Fra:74 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Light
# Fra:74 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera
# Fra:74 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera_target
# Fra:74 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Ground
# Fra:74 Mem:59.42M (Peak 113.59M) | Time:00:00.00 | Syncing Sphere
# Fra:74 Mem:59.58M (Peak 113.59M) | Time:00:00.00 | Rendering 1 / 5 samples
# Fra:74 Mem:59.57M (Peak 113.59M) | Time:00:00.12 | Rendering 4 / 4 samples
# Append frame 74
#  Time: 00:00.22 (Saving: 00:00.05)
#
# Fra:75 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Cube
# Fra:75 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Light
# Fra:75 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera
# Fra:75 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera_target
# Fra:75 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Ground
# Fra:75 Mem:59.42M (Peak 113.59M) | Time:00:00.00 | Syncing Sphere
# Fra:75 Mem:59.58M (Peak 113.59M) | Time:00:00.00 | Rendering 1 / 5 samples
# Fra:75 Mem:59.57M (Peak 113.59M) | Time:00:00.13 | Rendering 4 / 4 samples
# Append frame 75
#  Time: 00:00.22 (Saving: 00:00.05)
#
# Fra:76 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Cube
# Fra:76 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Light
# Fra:76 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera
# Fra:76 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera_target
# Fra:76 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Ground
# Fra:76 Mem:59.42M (Peak 113.59M) | Time:00:00.00 | Syncing Sphere
# Fra:76 Mem:59.58M (Peak 113.59M) | Time:00:00.00 | Rendering 1 / 5 samples
# Fra:76 Mem:59.57M (Peak 113.59M) | Time:00:00.12 | Rendering 4 / 4 samples
# Append frame 76
#  Time: 00:00.22 (Saving: 00:00.04)
#
# Fra:77 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Cube
# Fra:77 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Light
# Fra:77 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera
# Fra:77 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera_target
# Fra:77 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Ground
# Fra:77 Mem:59.42M (Peak 113.59M) | Time:00:00.00 | Syncing Sphere
# Fra:77 Mem:59.58M (Peak 113.59M) | Time:00:00.00 | Rendering 1 / 5 samples
# Fra:77 Mem:59.57M (Peak 113.59M) | Time:00:00.13 | Rendering 4 / 4 samples
# Append frame 77
#  Time: 00:00.22 (Saving: 00:00.05)
#
# Fra:78 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Cube
# Fra:78 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Light
# Fra:78 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera
# Fra:78 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera_target
# Fra:78 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Ground
# Fra:78 Mem:59.42M (Peak 113.59M) | Time:00:00.00 | Syncing Sphere
# Fra:78 Mem:59.58M (Peak 113.59M) | Time:00:00.00 | Rendering 1 / 5 samples
# Fra:78 Mem:59.57M (Peak 113.59M) | Time:00:00.12 | Rendering 4 / 4 samples
# Append frame 78
#  Time: 00:00.21 (Saving: 00:00.05)
#
# Fra:79 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Cube
# Fra:79 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Light
# Fra:79 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera
# Fra:79 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera_target
# Fra:79 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Ground
# Fra:79 Mem:59.42M (Peak 113.59M) | Time:00:00.00 | Syncing Sphere
# Fra:79 Mem:59.58M (Peak 113.59M) | Time:00:00.00 | Rendering 1 / 5 samples
# Fra:79 Mem:59.57M (Peak 113.59M) | Time:00:00.12 | Rendering 4 / 4 samples
# Append frame 79
#  Time: 00:00.20 (Saving: 00:00.04)
#
# Fra:80 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Cube
# Fra:80 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Light
# Fra:80 Mem:59.41M (Peak 113.59M) | Time:00:00.00 | Syncing Camera
# ...
# Fra:1775 Mem:59.71M (Peak 113.67M) | Time:00:00.00 | Rendering 1 / 5 samples
# Fra:1775 Mem:59.64M (Peak 113.67M) | Time:00:00.10 | Rendering 4 / 4 samples
# Append frame 1775
#  Time: 00:00.19 (Saving: 00:00.05)
#
# Fra:1776 Mem:59.47M (Peak 113.67M) | Time:00:00.00 | Syncing Cube
# Fra:1776 Mem:59.47M (Peak 113.67M) | Time:00:00.00 | Syncing Light
# Fra:1776 Mem:59.47M (Peak 113.67M) | Time:00:00.00 | Syncing Camera
# Fra:1776 Mem:59.47M (Peak 113.67M) | Time:00:00.00 | Syncing Camera_target
# Fra:1776 Mem:59.47M (Peak 113.67M) | Time:00:00.00 | Syncing Ground
# Fra:1776 Mem:59.48M (Peak 113.67M) | Time:00:00.00 | Syncing Sphere
# Fra:1776 Mem:59.71M (Peak 113.67M) | Time:00:00.00 | Rendering 1 / 5 samples
# Fra:1776 Mem:59.64M (Peak 113.67M) | Time:00:00.11 | Rendering 4 / 4 samples
# Append frame 1776
#  Time: 00:00.24 (Saving: 00:00.09)
#
# Fra:1777 Mem:59.47M (Peak 113.67M) | Time:00:00.00 | Syncing Cube
# Fra:1777 Mem:59.47M (Peak 113.67M) | Time:00:00.00 | Syncing Light
# Fra:1777 Mem:59.47M (Peak 113.67M) | Time:00:00.00 | Syncing Camera
# Fra:1777 Mem:59.47M (Peak 113.67M) | Time:00:00.00 | Syncing Camera_target
# Fra:1777 Mem:59.47M (Peak 113.67M) | Time:00:00.00 | Syncing Ground
# Fra:1777 Mem:59.48M (Peak 113.67M) | Time:00:00.00 | Syncing Sphere
# Fra:1777 Mem:59.71M (Peak 113.67M) | Time:00:00.00 | Rendering 1 / 5 samples
# Fra:1777 Mem:59.64M (Peak 113.67M) | Time:00:00.10 | Rendering 4 / 4 samples
# Append frame 1777
#  Time: 00:00.23 (Saving: 00:00.08)
#
# Fra:1778 Mem:59.47M (Peak 113.67M) | Time:00:00.00 | Syncing Cube
# Fra:1778 Mem:59.47M (Peak 113.67M) | Time:00:00.00 | Syncing Light
# Fra:1778 Mem:59.47M (Peak 113.67M) | Time:00:00.00 | Syncing Camera
# Fra:1778 Mem:59.47M (Peak 113.67M) | Time:00:00.00 | Syncing Camera_target
# Fra:1778 Mem:59.47M (Peak 113.67M) | Time:00:00.00 | Syncing Ground
# Fra:1778 Mem:59.48M (Peak 113.67M) | Time:00:00.00 | Syncing Sphere
# Fra:1778 Mem:59.71M (Peak 113.67M) | Time:00:00.00 | Rendering 1 / 5 samples
# Fra:1778 Mem:59.64M (Peak 113.67M) | Time:00:00.10 | Rendering 4 / 4 samples
# Append frame 1778
#  Time: 00:00.20 (Saving: 00:00.06)
#
# Fra:1779 Mem:59.47M (Peak 113.67M) | Time:00:00.00 | Syncing Cube
# Fra:1779 Mem:59.47M (Peak 113.67M) | Time:00:00.00 | Syncing Light
# Fra:1779 Mem:59.47M (Peak 113.67M) | Time:00:00.00 | Syncing Camera
# Fra:1779 Mem:59.47M (Peak 113.67M) | Time:00:00.00 | Syncing Camera_target
# Fra:1779 Mem:59.47M (Peak 113.67M) | Time:00:00.00 | Syncing Ground
# Fra:1779 Mem:59.48M (Peak 113.67M) | Time:00:00.00 | Syncing Sphere
# Fra:1779 Mem:59.71M (Peak 113.67M) | Time:00:00.00 | Rendering 1 / 5 samples
# Fra:1779 Mem:59.64M (Peak 113.67M) | Time:00:00.11 | Rendering 4 / 4 samples
# Append frame 1779
#  Time: 00:00.25 (Saving: 00:00.10)
#
# Fra:1780 Mem:59.47M (Peak 113.67M) | Time:00:00.00 | Syncing Cube
# Fra:1780 Mem:59.47M (Peak 113.67M) | Time:00:00.00 | Syncing Light
# Fra:1780 Mem:59.47M (Peak 113.67M) | Time:00:00.00 | Syncing Camera
# Fra:1780 Mem:59.47M (Peak 113.67M) | Time:00:00.00 | Syncing Camera_target
# Fra:1780 Mem:59.47M (Peak 113.67M) | Time:00:00.00 | Syncing Ground
# Fra:1780 Mem:59.48M (Peak 113.67M) | Time:00:00.00 | Syncing Sphere
# Fra:1780 Mem:59.71M (Peak 113.67M) | Time:00:00.00 | Rendering 1 / 5 samples
# Fra:1780 Mem:59.64M (Peak 113.67M) | Time:00:00.11 | Rendering 4 / 4 samples
# Append frame 1780
#  Time: 00:00.22 (Saving: 00:00.08)
#
# Fra:1781 Mem:59.47M (Peak 113.67M) | Time:00:00.00 | Syncing Cube
# Fra:1781 Mem:59.47M (Peak 113.67M) | Time:00:00.00 | Syncing Light
# Fra:1781 Mem:59.47M (Peak 113.67M) | Time:00:00.00 | Syncing Camera
# Fra:1781 Mem:59.47M (Peak 113.67M) | Time:00:00.00 | Syncing Camera_target
# Fra:1781 Mem:59.47M (Peak 113.67M) | Time:00:00.00 | Syncing Ground
# Fra:1781 Mem:59.48M (Peak 113.67M) | Time:00:00.00 | Syncing Sphere
# Fra:1781 Mem:59.71M (Peak 113.67M) | Time:00:00.00 | Rendering 1 / 5 samples
# Fra:1781 Mem:59.64M (Peak 113.67M) | Time:00:00.11 | Rendering 4 / 4 samples
# Append frame 